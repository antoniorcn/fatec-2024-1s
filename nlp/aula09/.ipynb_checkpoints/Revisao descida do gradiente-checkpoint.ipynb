# %% [markdown]
# # Exemplo de Regressão Linear

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
X = [150, 160, 155, 140, 170, 165, 152]
Y = [300000, 350000, 320000, 280000, 400000, 370000, 310000]

# %%
def calcula_yhat( x, W, B ):
    y_hat = (x * W) + B
    return y_hat

# %%
Y_hat = []

# %%
def derivada_wb(x, y, W, B ):
    m = len(x)
    soma_dw = 0
    soma_db = 0
    for i in range(m):
        valor_x = x[i]
        valor_y_real = y[i]
        valor_y_hat = valor_x * W + B
        dw_i = (valor_y_hat - valor_y_real) * valor_x
        db_i = (valor_y_hat - valor_y_real)
        soma_dw = soma_dw + dw_i
        soma_db = soma_db + db_i
    jdw_soma = soma_dw / m
    jdb_soma = soma_db / m
    return abs(jdw_soma), abs(jdb_soma)

# %%
calcular_custo_derivada_W(2140, -100)
# Out:
# 363402360

# %%
X
# Out:
# [150, 160, 155, 140, 170, 165, 152]

# %%
Y_hat
# Out:
# [48135000,
#  54768000,
#  51398000,
#  41930000,
#  61829000,
#  58245000,
#  49427360,
#  22500150,
#  25600160,
#  24025155,
#  19600140,
#  28900170,
#  27225165,
#  23104152,
#  150001,
#  160001,
#  155001,
#  140001,
#  170001,
#  165001,
#  152001,
#  -5397326808.642858,
#  -6140977377.600001,
#  -5763154768.407144,
#  -4701654837.4,
#  -6932606544.27143,
#  -6530794636.221429,
#  -5542218634.617144,
#  -35982178.724285714,
#  -38381108.61000001,
#  -37181643.66714286,
#  -33583248.83857143,
#  -40780038.49571429,
#  -39580573.552857146,
#  -36461964.70142858,
#  1312872063583.6267,
#  1493752613000.0437,
#  1401853654773.4365,
#  1143660982314.3982,
#  1686302630563.6494,
#  1588568938263.4482,
#  1348114616015.135,
#  8752480423.890844,
#  9335953831.250273,
#  9044217127.570559,
#  8169007016.531416,
#  9919427238.609703,
#  9627690534.929989,
#  8869175105.36273,
#  -319329740271774.75,
#  -363325315406080.3,
#  -340972732123570.44,
#  -278172530860325.94,
#  -410159256263242.5,
#  -386387490119304.3,
#  -327901786040807.3,
#  -2128864935145.1648,
#  -2270783221288.002,
#  -2199824078216.5835,
#  -1986946649002.3281,
#  -2412701507430.8384,
#  -2341742364359.42,
#  -2157248592373.7322,
#  7.767056157243045e+16,
#  8.837160374975843e+16,
#  8.293478571204496e+16,
#  6.76598949874982e+16,
#  9.976302151948216e+16,
#  9.398101568557082e+16,
#  7.975553996050438e+16,
#  517803743816202.94,
#  552322523435990.2,
#  535063133626096.56,
#  483284964196415.7,
#  586841303055777.4,
#  569581913245883.8,
#  524707499740160.4,
#  -1.8891807956175294e+19,
#  -2.149462206817534e+19,
#  -2.0172225008296333e+19,
#  -1.6456913875207125e+19,
#  -2.4265356211207266e+19,
#  -2.2858999135812317e+19,
#  -1.9398937176092754e+19,
#  -1.2594538637450195e+17,
#  -1.3434138792609587e+17,
#  -1.3014338715029891e+17,
#  -1.1754938482290803e+17,
#  -1.427373894776898e+17,
#  -1.3853938870189283e+17,
#  -1.2762458668482074e+17,
#  4.5950537839487793e+21,
#  5.228136168758372e+21,
#  4.906489578449205e+21,
#  4.002814582374146e+21,
#  -120382458.86646253,
#  -177507105.56505364,
#  -167218478.0389914,
#  -141905467.43005764,
#  -921302.9522927839,
#  -982731.1983965497,
#  -952017.0753446668,
#  -859874.7061890181,
#  -1044159.4445003156,
#  -1013445.3214484326,
#  -933588.6015135371,
#  200075612.4294812,
#  227638920.7272179,
#  213635001.98247814,
#  174290420.8987159,
#  256980345.79192603,
#  242087368.66370055,
#  205446024.74767086,
#  1333837.4161965414,
#  1422743.254545112,
#  1378290.3353708268,
#  1244931.5778479709,
#  1511649.0928936824,
#  1467196.1737193973,
#  1351618.5838662556,
#  -287812104.4689753,
#  -327467756.9985534,
#  -307320115.4384782,
#  -250714974.30168632,
#  -369681931.8904206,
#  -348255029.14920086,
#  -295538553.1859078,
#  -1918747.363126502,
#  -2046673.4812409587,
#  -1982710.4221837302,
#  -1790821.2450120451,
#  -2174599.5993554154,
#  -2110636.540298187,
#  -1944332.5867493933,
#  415868684.82292753,
#  473162124.1227119,
#  444053391.03045106,
#  362271353.0620918,
#  534151670.9614448,
#  503194884.09970975,
#  427031684.0797685,
#  2772457.898819517,
#  2957263.275766949,
#  2864860.587293233,
#  2587652.5218720846,
#  3142068.652714381,
#  3049665.964240665,
#  2809418.974209003,
#  -599049362.7800883,
#  -681586356.1893606,
#  -639652228.7156005,
#  -521837415.5238074,
#  -769448395.7516248,
#  -724851745.2013687,
#  -615130757.7697034,
#  -3993662.4185339217,
#  -4259914.726183504,
#  -4126788.572358713,
#  -3727410.1108843386,
#  -4526167.033833087,
#  -4393040.880008295,
#  -4046912.8800638383,
#  48135000,
#  54768000,
#  51398000,
#  41930000,
#  61829000,
#  58245000,
#  49427360]

# %%
# W = 20 e B = 1     Custo_Total    771724965287
# W = 200 e B = 1    Custo_Total    646745936807
# W = 2000 e B = 1   Custo_Total      6235708007
# W = 2050 e B = 1   Custo_Total      4257002207
# W = 2100 e B = 1   Custo_Total      3133066407
# W = 2200 e B = 1   Custo_Total      3449504807
# W = 2250 e B = 1   Custo_Total      4889879007
# W = 2500 e B = 1   Custo_Total     24913300007
# W = 4000 e B = 1   Custo_Total    593808076007 
# W = 10000 e B = 1  Custo_Total  10562317180007   
# W = 20000 e B = 1  Custo_Total  54529139020007

# %%
# Descida do Gradient para recalcular o W e o B
W = 1000
B = 1
taxa_aprendizagem = 0.000001
for era in range(100):
    custo_total_W, custo_total_B = derivada_wb(X, Y, W, B)
    print("Era:{}  Custo Total: {}".format(era, custo_total_W))
    W = W + taxa_aprendizagem * custo_total_W
    B = B + taxa_aprendizagem * custo_total_B
# Out:
# Era:0  Custo Total: 27859272.57142857
# Era:1  Custo Total: 27178865.827130858
# Era:2  Custo Total: 26515076.654353227
# Era:3  Custo Total: 25867499.202204965
# Era:4  Custo Total: 25235737.53189022
# Era:5  Custo Total: 24619405.374624968
# Era:6  Custo Total: 24018125.89546634
# Era:7  Custo Total: 23431531.46290993
# Era:8  Custo Total: 22859263.42411428
# Era:9  Custo Total: 22300971.88561503

# %%
plt.scatter(X, Y)
plt.plot(X, Y_hat, c="r")
plt.show()
