# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
X = np.linspace(-10, 10, 100)

# %%
W = -100
B = 0

# %%
reg_lin = X * W + B

# %%
def sigmoid( x ):
    return 1 / (1 + np.exp(-x))

# %%
x_sigmoid = sigmoid( X1 )

# %%
reg_lin_norm = sigmoid(reg_lin / np.linalg.norm(reg_lin))

# %%
plt.plot(X1, x_sigmoid)
plt.plot(X1, reg_lin_norm)
plt.show()
